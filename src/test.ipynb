# %%
data=""" c7c5
position startpos moves e2e4
d

 +---+---+---+---+---+---+---+---+
 | r | n | b | q | k | b | n | r | 8
 +---+---+---+---+---+---+---+---+
 | p | p | p | p | p | p | p | p | 7
 +---+---+---+---+---+---+---+---+
 |   |   |   |   |   |   |   |   | 6
 +---+---+---+---+---+---+---+---+
 |   |   |   |   |   |   |   |   | 5
 +---+---+---+---+---+---+---+---+
 |   |   |   |   | P |   |   |   | 4
 +---+---+---+---+---+---+---+---+
 |   |   |   |   |   |   |   |   | 3
 +---+---+---+---+---+---+---+---+
 | P | P | P | P |   | P | P | P | 2
 +---+---+---+---+---+---+---+---+
 | R | N | B | Q | K | B | N | R | 1
 +---+---+---+---+---+---+---+---+
 
"""
#print(data)

# %%
import re
#print(data)
#row1=re.match(r".*\| (.) \| (.) \| (.) \| (.) \| (.) \| (.) \| (.) \| (.) \| 8",data)
#print(row1)
#row1=re.match(r".*\| (.)",data)
#print(row1.group(1))
board=[None]*8

for row in re.findall(r".*\| (.) \| (.) \| (.) \| (.) \| (.) \| (.) \| (.) \| (.) \| (.)",data):
    board[8-int(row[8])]=row[:8]
print(board[7][7])
board
# Out:
# R
# [('r', 'n', 'b', 'q', 'k', 'b', 'n', 'r'),
#  ('p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'),
#  (' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '),
#  (' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '),
#  (' ', ' ', ' ', ' ', 'P', ' ', ' ', ' '),
#  (' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '),
#  ('P', 'P', 'P', 'P', ' ', 'P', 'P', 'P'),
#  ('R', 'N', 'B', 'Q', 'K', 'B', 'N', 'R')]

# %%
from AlphaZero_player import AlphaZero

a=AlphaZero('/home/owensr/chess/data/model_data/random.gz',8)
moves=['e2e4','h7h6','g1f3','g8f6','b1c3','b8c6','d2d3','e7e6','d3d4','f6e4','c3e4','a7a5','a2a3','f7f5','e4d2','d8f6','f1e2','a8b8','a3a4','g7g6','d2c4','b7b5','c4e3','e6e5','e1g1','e8f7','d4e5','g6g5','a4b5','f7e6','d1d5','e6e7','d5d1','g5g4','f3h4','e7f7','e2c4','f7e8','h4g6','c6d4','d1d4','f8c5','d4c5','c7c6','a1a5','h6h5','a5a8','f6d6','c5a7','c6c5','c4d5','h8f8','g2g3','d6f6','b2b4','b8a8','a7d7','c8d7','e5f6','e8d8','g6f4','a8a3','f1d1','a3a8','d5a8','f8f6','c1d2','f6f8','d2e1','f8g8','f2f3','c5b4','g1g2','d8e8','d1d5','d7e6','a8c6','e8e7','g2f2','e6f7','f3g4','f7d5','e3d5','e7f8','f2e2','b4b3','f4e6','f8f7','c2b3','g8f8','g4f5','h5h4','g3g4','f8b8','d5e3','f7e7','b3b4','e7f6','e6d4','b8d8','d4c2','d8b8','c6d7','f6e7','e3c4','e7d7','e1h4','d7c7','c4e3','c7d7','c2a3','b8f8','h4g3','d7c8','h2h4','f8h8','g4g5','h8d8','h4h5','d8d6','g3f4','d6f6','e2d3','f6b6','a3c4','c8d8','d3e4','b6b7','f4d6','b7a7','h5h6','a7a1','h6h7','a1a2','h7h8r','d8d7','d6b8','a2b2','c4b6','d7e7','f5f6','e7e6','h8e8','e6f7','g5g6','f7f6','e8f8','f6g5','b8e5','b2f2','f8f5','f2f5','e3f5','g5f5','g5g6','f5e6','g5g4','e6f5','g5g6','f5g6','g5g6']

a.getBoard(moves)
# Out:
# Alpha 8 /home/owensr/chess/data/model_data/random.gz
# ...
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', 'N', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', 'P', ' ', ' ', 'B', ' ', ' ', ' '],
#  [' ', 'P', ' ', ' ', 'K', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]

# %%
from AlphaZero_player import AlphaZero

a=AlphaZero('/home/owensr/chess/data/model_data/random.gz',8)
moves=['e2e4','h7h6','g1f3','g8f6','b1c3','b8c6','d2d3','e7e6','d3d4','f6e4','c3e4','a7a5','a2a3','f7f5','e4d2','d8f6','f1e2','a8b8','a3a4','g7g6','d2c4','b7b5','c4e3','e6e5','e1g1','e8f7','d4e5','g6g5','a4b5','f7e6','d1d5','e6e7','d5d1','g5g4','f3h4','e7f7','e2c4','f7e8','h4g6','c6d4','d1d4','f8c5','d4c5','c7c6','a1a5','h6h5','a5a8','f6d6','c5a7','c6c5','c4d5','h8f8','g2g3','d6f6','b2b4','b8a8','a7d7','c8d7','e5f6','e8d8','g6f4','a8a3','f1d1','a3a8','d5a8','f8f6','c1d2','f6f8','d2e1','f8g8','f2f3','c5b4','g1g2','d8e8','d1d5','d7e6','a8c6','e8e7','g2f2','e6f7','f3g4','f7d5','e3d5','e7f8','f2e2','b4b3','f4e6','f8f7','c2b3','g8f8','g4f5','h5h4','g3g4','f8b8','d5e3','f7e7','b3b4','e7f6','e6d4','b8d8','d4c2','d8b8','c6d7','f6e7','e3c4','e7d7','e1h4','d7c7','c4e3','c7d7','c2a3','b8f8','h4g3','d7c8','h2h4','f8h8','g4g5','h8d8','h4h5','d8d6','g3f4','d6f6','e2d3','f6b6','a3c4','c8d8','d3e4','b6b7','f4d6','b7a7','h5h6','a7a1','h6h7','a1a2','h7h8r','d8d7','d6b8','a2b2','c4b6','d7e7','f5f6','e7e6','h8e8','e6f7','g5g6','f7f6','e8f8','f6g5','b8e5','b2f2','f8f5','f2f5','e3f5','g5f5','g5g6','f5e6','g5g4','e6f5','g5g6','f5g6','g5g6']

a.getBoard(moves)
